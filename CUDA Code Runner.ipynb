# %%
# !nvcc --version
# !nvidia-smi
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2025 NVIDIA Corporation
# Built on Fri_Feb_21_20:23:50_PST_2025
# Cuda compilation tools, release 12.8, V12.8.93
# Build cuda_12.8.r12.8/compiler.35583870_0
# Mon Mar  9 17:58:00 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# ...

# %%
# !pip install nvcc4jupyter
# %load_ext nvcc4jupyter
# Out:
# ...
# Detected platform "Colab". Running its setup...
# Source files will be saved in "/tmp/tmpmt4_v7qd".

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/Machine Learning/learning-cuda
# Out:
# /content/drive/My Drive/Machine Learning/learning-cuda

# %%
# !nvcc -arch=sm_75 02_compare_conv.cu -o 02_compare_conv -lcudnn -lcuda

# %%
# !./02_compare_conv
# Out:
# Image size: 224x224x32
# Kernel size: 11x11x32x64
# Batch size: 4
# cuDNN average time: 40.161560 ms
# Naive kernel average time: 213.217743 ms
# Max difference between cuDNN and naive kernel: 0.000000e+00
